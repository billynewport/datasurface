# %%
import SqlAlchemyUtils
from Governance import Dataset

d : Dataset = SqlAlchemyUtils.convertSQLAlchemyTableToDataset()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/billy/Documents/Code/DataGlide/src/dataglide/md/Scratch.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/billy/Documents/Code/DataGlide/src/dataglide/md/Scratch.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import SqlAlchemyUtils
#       <a href='vscode-notebook-cell:/Users/billy/Documents/Code/DataGlide/src/dataglide/md/Scratch.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> from Governance import Dataset
#       <a href='vscode-notebook-cell:/Users/billy/Documents/Code/DataGlide/src/dataglide/md/Scratch.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> d : Dataset = SqlAlchemyUtils.convertSQLAlchemyTableToDataset()
#
# File ~/Documents/Code/DataGlide/src/dataglide/md/SqlAlchemyUtils.py:3
#       1 import decimal
#       2 from typing import Any, List, Optional, TypeVar
# ----> 3 import Schema
#       4 import sqlalchemy
# ...
